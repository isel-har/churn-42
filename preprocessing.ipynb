# %%
from sklearn.preprocessing import  OneHotEncoder
import pandas as pd
import numpy as np
import joblib

CAT_NA_VALUE = "__MISSING__"
pd.set_option('display.max_rows', None)


df = pd.read_csv("data/bank_data_train.csv", nrows=1000)

categorical_cols = df.select_dtypes(exclude="number").columns.to_list()
numerical_cols   = df.select_dtypes(include='number').columns.to_list()
numerical_cols   = [c for c in numerical_cols if c not in ("ID", "TARGET")]
dtypes_dict      = df.dtypes.to_dict()

nan_counts       = pd.Series(0.0, index=df.columns.to_list())

del df

samples = 0
chunks = pd.read_csv(
        "data/bank_data_train.csv",
        dtype=dtypes_dict,
        chunksize=100_000
)

for chunk in chunks:
    nan_counts += chunk.isna().sum()
    samples    += len(chunk)

nan_counts    = (nan_counts / samples) * 100
kept_cols       = nan_counts[nan_counts <= 40]
print("NaN percentage of each feature")
print(nan_counts)
# Out:
# NaN percentage of each feature
# ID                              0.000000
# CR_PROD_CNT_IL                  0.000000
# AMOUNT_RUB_CLO_PRC             10.789437
# PRC_ACCEPTS_A_EMAIL_LINK       56.315493
# APP_REGISTR_RGN_CODE           82.952786
# PRC_ACCEPTS_A_POS              56.315493
# PRC_ACCEPTS_A_TK               56.315493
# TURNOVER_DYNAMIC_IL_1M          0.000000
# CNT_TRAN_AUT_TENDENCY1M        78.289929
# SUM_TRAN_AUT_TENDENCY1M        78.289929
# AMOUNT_RUB_SUP_PRC             10.789437
# PRC_ACCEPTS_A_AMOBILE          56.315493
# SUM_TRAN_AUT_TENDENCY3M        68.734480
# CLNT_TRUST_RELATION            80.455249
# PRC_ACCEPTS_TK                 56.315493
# PRC_ACCEPTS_A_MTP              56.315493
# REST_DYNAMIC_FDEP_1M            0.000000
# CNT_TRAN_AUT_TENDENCY3M        68.734480
# CNT_ACCEPTS_TK                 56.315493
# APP_MARITAL_STATUS             80.789437
# REST_DYNAMIC_SAVE_3M            0.000000
# CR_PROD_CNT_VCU                 0.000000
# REST_AVG_CUR                    0.000000
# CNT_TRAN_MED_TENDENCY1M        80.583068
# APP_KIND_OF_PROP_HABITATION    83.287536
# CLNT_JOB_POSITION_TYPE         87.392382
# AMOUNT_RUB_NAS_PRC             10.789437
# CLNT_JOB_POSITION              40.648385
# APP_DRIVING_LICENSE            83.879895
# TRANS_COUNT_SUP_PRC            10.789437
# APP_EDUCATION                  80.826037
# CNT_TRAN_CLO_TENDENCY1M        81.335060
# SUM_TRAN_MED_TENDENCY1M        80.583068
# PRC_ACCEPTS_A_ATM              56.315493
# PRC_ACCEPTS_MTP                56.315493
# TRANS_COUNT_NAS_PRC            10.789437
# APP_TRAVEL_PASS                83.879895
# CNT_ACCEPTS_MTP                56.315493
# CR_PROD_CNT_TOVR                0.000000
# APP_CAR                        83.880177
# CR_PROD_CNT_PIL                 0.000000
# SUM_TRAN_CLO_TENDENCY1M        81.335060
# APP_POSITION_TYPE              82.954194
# TURNOVER_CC                     0.000000
# TRANS_COUNT_ATM_PRC            10.789437
# AMOUNT_RUB_ATM_PRC             10.789437
# TURNOVER_PAYM                   0.000000
# AGE                             0.000000
# CNT_TRAN_MED_TENDENCY3M        67.376052
# CR_PROD_CNT_CC                  0.000000
# SUM_TRAN_MED_TENDENCY3M        67.376052
# REST_DYNAMIC_FDEP_3M            0.000000
# REST_DYNAMIC_IL_1M              0.000000
# APP_EMP_TYPE                   81.034939
# SUM_TRAN_CLO_TENDENCY3M        67.651679
# LDEAL_TENOR_MAX                97.747403
# LDEAL_YQZ_CHRG                 99.650610
# CR_PROD_CNT_CCFP                0.000000
# DEAL_YQZ_IR_MAX                97.747403
# LDEAL_YQZ_COM                  99.650891
# DEAL_YQZ_IR_MIN                97.747403
# CNT_TRAN_CLO_TENDENCY3M        67.651679
# REST_DYNAMIC_CUR_1M             0.000000
# REST_AVG_PAYM                   0.000000
# LDEAL_TENOR_MIN                97.747403
# LDEAL_AMT_MONTH                99.468454
# APP_COMP_TYPE                  81.034939
# LDEAL_GRACE_DAYS_PCT_MED        0.000000
# REST_DYNAMIC_CUR_3M             0.000000
# CNT_TRAN_SUP_TENDENCY3M        44.053042
# TURNOVER_DYNAMIC_CUR_1M         0.000000
# REST_DYNAMIC_PAYM_3M            0.000000
# SUM_TRAN_SUP_TENDENCY3M        44.053042
# REST_DYNAMIC_IL_3M              0.000000
# CNT_TRAN_ATM_TENDENCY3M        28.039922
# CNT_TRAN_ATM_TENDENCY1M        42.038346
# TURNOVER_DYNAMIC_IL_3M          0.000000
# SUM_TRAN_ATM_TENDENCY3M        28.039922
# DEAL_GRACE_DAYS_ACC_S1X1       80.165827
# AVG_PCT_MONTH_TO_PCLOSE        99.541654
# DEAL_YWZ_IR_MIN                73.053014
# SUM_TRAN_SUP_TENDENCY1M        56.081252
# DEAL_YWZ_IR_MAX                73.053014
# SUM_TRAN_ATM_TENDENCY1M        42.038346
# REST_DYNAMIC_PAYM_1M            0.000000
# CNT_TRAN_SUP_TENDENCY1M        56.081252
# DEAL_GRACE_DAYS_ACC_AVG        80.451871
# TURNOVER_DYNAMIC_CUR_3M         0.000000
# PACK                            0.000000
# MAX_PCLOSE_DATE                99.470424
# LDEAL_YQZ_PC                   99.209437
# CLNT_SETUP_TENOR                0.000000
# DEAL_GRACE_DAYS_ACC_MAX        80.451871
# TURNOVER_DYNAMIC_PAYM_3M        0.000000
# LDEAL_DELINQ_PER_MAXYQZ        97.747403
# TURNOVER_DYNAMIC_PAYM_1M        0.000000
# CLNT_SALARY_VALUE              99.799544
# TRANS_AMOUNT_TENDENCY3M        14.638926
# MED_DEBT_PRC_YQZ               97.747403
# TRANS_CNT_TENDENCY3M           14.638926
# LDEAL_USED_AMT_AVG_YQZ         97.747403
# REST_DYNAMIC_CC_1M              0.000000
# LDEAL_USED_AMT_AVG_YWZ         73.053014
# TURNOVER_DYNAMIC_CC_1M          0.000000
# AVG_PCT_DEBT_TO_DEAL_AMT       99.468454
# LDEAL_ACT_DAYS_ACC_PCT_AVG     73.690701
# REST_DYNAMIC_CC_3M              0.000000
# MED_DEBT_PRC_YWZ               73.053014
# LDEAL_ACT_DAYS_PCT_TR3         73.690701
# LDEAL_ACT_DAYS_PCT_AAVG        72.359864
# LDEAL_DELINQ_PER_MAXYWZ        73.053014
# TURNOVER_DYNAMIC_CC_3M          0.000000
# LDEAL_ACT_DAYS_PCT_TR          73.690701
# LDEAL_ACT_DAYS_PCT_TR4         73.690701
# LDEAL_ACT_DAYS_PCT_CURR        73.690701
# TARGET                          0.000000
# dtype: float64

# %%
kept_num_cols = [n for n in numerical_cols if n in kept_cols.index.to_list()]
kept_cat_cols = [n for n in categorical_cols if n in kept_cols.index.to_list()]
print("Kept feature")
print(kept_cols)

del kept_cols

chunks = pd.read_csv(
        "data/bank_data_train.csv",
        dtype=dtypes_dict,
        chunksize=100_000
)


unique_categories = {}
for cat in kept_cat_cols:
    unique_categories[cat] = set()

sum_x   = pd.Series(0.0, index=kept_num_cols)
sum_x2  = pd.Series(0.0, index=kept_num_cols)
for chunk in chunks:
        # ---- categorical stats ----

    for col in kept_cat_cols:
        unique_categories[col].add(CAT_NA_VALUE)
        unique_categories[col].update(
            chunk[col].fillna(CAT_NA_VALUE).astype(str).unique()
        )
        # ---- numerical stats ----
    chunk[kept_num_cols] = chunk[kept_num_cols].fillna(0.0)

    sum_x   += chunk[kept_num_cols].sum(axis=0)
    sum_x2  += chunk[kept_num_cols].pow(2).sum(axis=0)


mean     = sum_x / samples
variance = (sum_x2 / samples) - (mean ** 2)
std_dev  = np.sqrt(variance)

encoders = []

    # ---- encoders ----
    # onehot_encoder = None
for cat in kept_cat_cols:
    encoder = OneHotEncoder(categories=unique_categories[cat])
    encoders.append(encoder)


preprocessor = {
    "mean":mean.to_numpy(),
    "std" : std_dev,
    "encoders":encoders,
    "kept_num_cols":kept_num_cols,
    "kept_cat_cols":kept_cat_cols,
    "dtypes":dtypes_dict
}

joblib.dump(preprocessor, "preprocessor.joblib")
print("preprocessing saved!")
# Out:
# Kept feature
# ID                           0.000000
# CR_PROD_CNT_IL               0.000000
# AMOUNT_RUB_CLO_PRC          10.789437
# TURNOVER_DYNAMIC_IL_1M       0.000000
# AMOUNT_RUB_SUP_PRC          10.789437
# REST_DYNAMIC_FDEP_1M         0.000000
# REST_DYNAMIC_SAVE_3M         0.000000
# CR_PROD_CNT_VCU              0.000000
# REST_AVG_CUR                 0.000000
# AMOUNT_RUB_NAS_PRC          10.789437
# TRANS_COUNT_SUP_PRC         10.789437
# TRANS_COUNT_NAS_PRC         10.789437
# CR_PROD_CNT_TOVR             0.000000
# CR_PROD_CNT_PIL              0.000000
# TURNOVER_CC                  0.000000
# TRANS_COUNT_ATM_PRC         10.789437
# AMOUNT_RUB_ATM_PRC          10.789437
# TURNOVER_PAYM                0.000000
# AGE                          0.000000
# CR_PROD_CNT_CC               0.000000
# REST_DYNAMIC_FDEP_3M         0.000000
# REST_DYNAMIC_IL_1M           0.000000
# CR_PROD_CNT_CCFP             0.000000
# REST_DYNAMIC_CUR_1M          0.000000
# REST_AVG_PAYM                0.000000
# LDEAL_GRACE_DAYS_PCT_MED     0.000000
# REST_DYNAMIC_CUR_3M          0.000000
# TURNOVER_DYNAMIC_CUR_1M      0.000000
# REST_DYNAMIC_PAYM_3M         0.000000
# REST_DYNAMIC_IL_3M           0.000000
# CNT_TRAN_ATM_TENDENCY3M     28.039922
# TURNOVER_DYNAMIC_IL_3M       0.000000
# SUM_TRAN_ATM_TENDENCY3M     28.039922
# REST_DYNAMIC_PAYM_1M         0.000000
# TURNOVER_DYNAMIC_CUR_3M      0.000000
# PACK                         0.000000
# CLNT_SETUP_TENOR             0.000000
# TURNOVER_DYNAMIC_PAYM_3M     0.000000
# TURNOVER_DYNAMIC_PAYM_1M     0.000000
# TRANS_AMOUNT_TENDENCY3M     14.638926
# TRANS_CNT_TENDENCY3M        14.638926
# REST_DYNAMIC_CC_1M           0.000000
# TURNOVER_DYNAMIC_CC_1M       0.000000
# REST_DYNAMIC_CC_3M           0.000000
# TURNOVER_DYNAMIC_CC_3M       0.000000
# TARGET                       0.000000
# dtype: float64
# preprocessing saved!
