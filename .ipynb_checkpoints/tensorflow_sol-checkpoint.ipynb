# %%
from sklearn.metrics import roc_auc_score, accuracy_score
from lib.tf_modules import TNet, Dense
import pandas as pd
import joblib
import numpy as np
import tensorflow as tf
import sklearn

sklearn.set_config(transform_output="pandas")
pd.set_option('display.max_colwidth', None)

transformer = joblib.load("transformer.pkl")
train_df = pd.read_csv("data/balanced_train_data.csv")
y = train_df['TARGET'].copy().astype(np.float32)
train_df = train_df.drop(columns=['TARGET'])

X_transformed = transformer.transform(train_df).astype(np.float32)

del train_df

model = TNet(layers=[
    Dense(in_features=X_transformed.shape[1], out_features=64, activation=tf.nn.relu),
    Dense(in_features=64, out_features=32, activation=tf.nn.relu),
    Dense(in_features=32, out_features=16, activation=tf.nn.relu),
    Dense(in_features=16, out_features=1, activation=tf.nn.sigmoid),
])

model.fit(X_transformed, y, epochs=10, learning_rate=0.001)

del X_transformed
del y

test_df = pd.read_csv("data/split_data_test.csv")
y_test = test_df['TARGET'].astype(np.float32)
X_test = test_df.drop(columns=['TARGET'])
X_transformed_test = transformer.transform(X_test).astype(np.float32)

del X_test

y_prob = model.predict(X_transformed_test)
y_pred = (y_prob > 0.5).astype(int)

result = pd.DataFrame({
    'library': ["scikit-learn, tensorflow"],
    'algorithm': ['Multilayer-perceptron'],
    'hyerparamters': ['hidden layers : (64, 32, 16) + relu activation, epochs 10, learning rate 0.001 batch_size 32'],
    'Accuracy': [accuracy_score(y_test, y_pred)],
    'AUC': [roc_auc_score(y_test, y_prob)]
}, index=None)

print(result.T)
# Out:
# Epoch 0, Average Loss: 0.3310
# Epoch 1, Average Loss: 0.2819
# Epoch 2, Average Loss: 0.2733
# Epoch 3, Average Loss: 0.2679
# Epoch 4, Average Loss: 0.2639
# Epoch 5, Average Loss: 0.2605
# Epoch 6, Average Loss: 0.2575
# Epoch 7, Average Loss: 0.2548
# Epoch 8, Average Loss: 0.2523
# Epoch 9, Average Loss: 0.2500
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 41
#      38 del X_test
#      40 y_prob = model.predict(X_transformed_test)
# ---> 41 y_pred = (y_prob > 0.5).astype(int)
#      43 result = pd.DataFrame({
#      44     'library': ["scikit-learn, tensorflow"],
#      45     'algorithm': ['Multilayer-perceptron'],
#    (...)
#      48     'AUC': [roc_auc_score(y_test, y_prob)]
#      49 }, index=None)
#      51 print(result.T)
#
# File D:\codes\ai_ml\.venv\lib\site-packages\tensorflow\python\framework\tensor.py:255, in Tensor.__getattr__(self, name)
#     251 def __getattr__(self, name):
#     252   if name in {"T", "astype", "ravel", "transpose", "reshape", "clip", "size",
#     253               "tolist", "data"}:
#     254     # TODO(wangpeng): Export the enable_numpy_behavior knob
# --> 255     raise AttributeError(
#     256         f"{type(self).__name__} object has no attribute '{name}'. " + """
#     257       If you are looking for numpy-related methods, please run the following:
#     258       tf.experimental.numpy.experimental_enable_numpy_behavior()
#     259     """)
#     260   self.__getattribute__(name)
#
# AttributeError: EagerTensor object has no attribute 'astype'.
#         If you are looking for numpy-related methods, please run the following:
#         tf.experimental.numpy.experimental_enable_numpy_behavior()
