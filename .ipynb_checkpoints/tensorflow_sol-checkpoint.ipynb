# %%
from sklearn.metrics import roc_auc_score, accuracy_score
from sklearn.model_selection import GridSearchCV
import pandas as pd
import joblib
import numpy as np
import sklearn
from lib.tnn_wrapper import TNetWrapper


sklearn.set_config(transform_output="pandas")
pd.set_option('display.max_colwidth', None)


transformer = joblib.load("transformer.pkl")
train_df = pd.read_csv("data/balanced_train_data.csv")
y = train_df['TARGET'].copy().astype(np.float32)
train_df = train_df.drop(columns=['TARGET'])
X_transformed = transformer.transform(train_df).astype(np.float32)
del train_df


param_grid = {
    # "hidden_units": [8, 16, 32],
    # "learning_rate": [0.01, 0.001],
    "epochs": [10]
}

grid = GridSearchCV(TNetWrapper(), param_grid=param_grid, scoring='roc_auc_ovr')
grid.fit(X_transformed, y)


del X_transformed, y

test_df = pd.read_csv("data/split_data_test.csv")
y_test = test_df['TARGET'].astype(np.float32)
X_test = test_df.drop(columns=['TARGET'])
X_transformed_test = transformer.transform(X_test).astype(np.float32)

del X_test

model = grid.best_estimator_

y_prob = model.predict(X_transformed_test)
y_pred = (y_prob > 0.5).astype(int)

best_params = {
    "hidden_units":model.hidden_units,
    "epochs" : model.epochs,
    "learning_rate" : model.learning_rate,
    "batch_size" : model.batch_size
}


result = pd.DataFrame({
    'library': ["scikit-learn, tensorflow"],
    'algorithm': ['Multilayer-perceptron'],
    'hyerparamters': [str(best_params)],
    'Accuracy': [accuracy_score(y_test, y_pred)],
    'AUC': [roc_auc_score(y_test, y_prob)]
}, index=None)

print(result.T)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776004772.007370  604684 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776004772.014274  604683 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776004772.034408  604685 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1776004772.152716  604685 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1776004772.163951  604683 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1776004772.168766  604684 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776004774.189432  604684 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1776004774.189433  604685 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776004774.189605  604683 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# E0000 00:00:1776004779.503207  604684 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# E0000 00:00:1776004779.514492  604683 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# E0000 00:00:1776004779.637852  604685 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# W0000 00:00:1776004779.918097  604683 cpu_allocator_impl.cc:82] Allocation of 33340340 exceeds 10% of free system memory.
# W0000 00:00:1776004779.927570  604684 cpu_allocator_impl.cc:82] Allocation of 33340560 exceeds 10% of free system memory.
# W0000 00:00:1776004780.048092  604685 cpu_allocator_impl.cc:82] Allocation of 33340340 exceeds 10% of free system memory.
# W0000 00:00:1776004780.048971  604683 cpu_allocator_impl.cc:82] Allocation of 33340340 exceeds 10% of free system memory.
# W0000 00:00:1776004780.062792  604684 cpu_allocator_impl.cc:82] Allocation of 33340560 exceeds 10% of free system memory.
# W0000 00:00:1776004780.102910  604685 cpu_allocator_impl.cc:82] Allocation of 33340340 exceeds 10% of free system memory.
# /home/isel-har/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/isel-har/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/home/isel-har/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/home/isel-har/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "/home/isel-har/.local/lib/python3.10/site-packages/sklearn/utils/validation.py", line 2286, in _check_response_method
#     raise AttributeError(
# AttributeError: TNetWrapper has none of the following attributes: predict_proba.
#
#   warnings.warn(
# /home/isel-har/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/isel-har/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/home/isel-har/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/home/isel-har/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "/home/isel-har/.local/lib/python3.10/site-packages/sklearn/utils/validation.py", line 2286, in _check_response_method
#     raise AttributeError(
# AttributeError: TNetWrapper has none of the following attributes: predict_proba.
#
#   warnings.warn(
# /home/isel-har/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/isel-har/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/home/isel-har/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/home/isel-har/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "/home/isel-har/.local/lib/python3.10/site-packages/sklearn/utils/validation.py", line 2286, in _check_response_method
#     raise AttributeError(
# AttributeError: TNetWrapper has none of the following attributes: predict_proba.
#
#   warnings.warn(
# /home/isel-har/.local/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1135: UserWarning: One or more of the test scores are non-finite: [nan]
#   warnings.warn(
# W0000 00:00:1776005121.964929  597623 cpu_allocator_impl.cc:82] Allocation of 50010620 exceeds 10% of free system memory.
# W0000 00:00:1776005122.004191  597623 cpu_allocator_impl.cc:82] Allocation of 50010620 exceeds 10% of free system memory.
# Epoch 0, Average Loss: 0.3831
# Epoch 1, Average Loss: 0.2830
# Epoch 2, Average Loss: 0.2740
# Epoch 3, Average Loss: 0.2690
# Epoch 4, Average Loss: 0.2654
# Epoch 5, Average Loss: 0.2625
# Epoch 6, Average Loss: 0.2600
# Epoch 0, Average Loss: 0.3401
# Epoch 1, Average Loss: 0.2985
# Epoch 2, Average Loss: 0.2866
# Epoch 3, Average Loss: 0.2793
# Epoch 4, Average Loss: 0.2742
# Epoch 5, Average Loss: 0.2705
# Epoch 6, Average Loss: 0.2676
# Epoch 7, Average Loss: 0.2652
# Epoch 8, Average Loss: 0.2632
# Epoch 9, Average Loss: 0.2615
# Epoch 0, Average Loss: 0.3914
# Epoch 1, Average Loss: 0.2888
# Epoch 2, Average Loss: 0.2778
# Epoch 3, Average Loss: 0.2720
# Epoch 4, Average Loss: 0.2679
# Epoch 5, Average Loss: 0.2649
# Epoch 6, Average Loss: 0.2624
# Epoch 7, Average Loss: 0.2603
# Epoch 8, Average Loss: 0.2585
# Epoch 9, Average Loss: 0.2570
# Epoch 7, Average Loss: 0.2578
# Epoch 0, Average Loss: 0.4102
# Epoch 1, Average Loss: 0.2925
# Epoch 2, Average Loss: 0.2813
# Epoch 3, Average Loss: 0.2752
# Epoch 4, Average Loss: 0.2710
# Epoch 5, Average Loss: 0.2679
# Epoch 6, Average Loss: 0.2653
# Epoch 7, Average Loss: 0.2632
# Epoch 8, Average Loss: 0.2614
# Epoch 9, Average Loss: 0.2598
# Epoch 8, Average Loss: 0.2559
# Epoch 9, Average Loss: 0.2542
#                                                                                           0
# library                                                            scikit-learn, tensorflow
# algorithm                                                             Multilayer-perceptron
# hyerparamters  {'hidden_units': 10, 'epochs': 10, 'learning_rate': 0.001, 'batch_size': 32}
# Accuracy                                                                            0.91841
# AUC                                                                                0.500703
