# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

from sklearn.metrics import roc_auc_score, accuracy_score
from sklearn.model_selection import GridSearchCV
import pandas as pd
import joblib
import numpy as np
import sklearn
from lib.tnn_wrapper import TNetWrapper

import warnings
warnings.filterwarnings("ignore")


sklearn.set_config(transform_output="pandas")
pd.set_option('display.max_colwidth', None)


transformer = joblib.load("transformer.pkl")
train_df = pd.read_csv("data/balanced_train_data.csv")
y = train_df['TARGET'].copy().astype(np.float32)
train_df = train_df.drop(columns=['TARGET'])
X_transformed = transformer.transform(train_df).astype(np.float32)

del train_df

param_grid = {
    "hidden_units": [32, 64],
    "epochs": [10, 12]
}

grid = GridSearchCV(
    TNetWrapper(),
    param_grid=param_grid,
    scoring='roc_auc_ovr',
    n_jobs=-1
)

grid.fit(X_transformed, y)

del X_transformed, y

test_df = pd.read_csv("data/split_data_test.csv")
y_test = test_df['TARGET'].astype(np.float32)
X_test = test_df.drop(columns=['TARGET'])
X_transformed_test = transformer.transform(X_test).astype(np.float32)

del X_test

best_model = grid.best_estimator_

y_prob = best_model.predict_proba(X_transformed_test).numpy()
y_pred = (y_prob > 0.5).astype(int)

best_params = {
    "hidden_units":best_model.hidden_units,
    "epochs" : best_model.epochs,
    "learning_rate" : best_model.learning_rate,
    "batch_size" : best_model.batch_size
}

result = pd.DataFrame({
    'library': ["scikit-learn, tensorflow"],
    'algorithm': ['Multilayer-perceptron'],
    'hyerparamters': [str(best_params)],
    'Accuracy': [accuracy_score(y_test, y_pred)],
    'AUC': [roc_auc_score(y_test, y_prob)]
}, index=None)

print(result.T)
# Out:
# Epoch 0, Average Loss: 0.3417
# Epoch 1, Average Loss: 0.2842
# Epoch 2, Average Loss: 0.2745
# Epoch 3, Average Loss: 0.2687
# Epoch 4, Average Loss: 0.2645
# Epoch 5, Average Loss: 0.2613
# Epoch 6, Average Loss: 0.2586
# Epoch 7, Average Loss: 0.2564
# Epoch 8, Average Loss: 0.2545
# Epoch 9, Average Loss: 0.2528
#                                                                                           0
# library                                                            scikit-learn, tensorflow
# algorithm                                                             Multilayer-perceptron
# hyerparamters  {'hidden_units': 32, 'epochs': 10, 'learning_rate': 0.001, 'batch_size': 32}
# Accuracy                                                                           0.917988
# AUC                                                                                0.747217
