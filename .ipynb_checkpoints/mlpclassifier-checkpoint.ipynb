# %%
import sklearn
import pandas as pd

from sklearn.utils.class_weight import compute_sample_weight
from sklearn.metrics import roc_auc_score, accuracy_score
from sklearn.neural_network import MLPClassifier
import joblib
import numpy as np

sklearn.set_config(transform_output="pandas")
pd.set_option('display.max_colwidth', None)

model = MLPClassifier(
    early_stopping=True,
    solver='adam',
    activation='relu',
    max_iter=300,
    hidden_layer_sizes=(128, 64, 32),
    batch_size=32
)

transformer = joblib.load("transformer.pkl")
train_df    = pd.read_csv("data/balanced_train_data.csv")

y        = train_df['TARGET'].astype(np.float32)
train_df = train_df.drop(columns=['TARGET'])

X_transformed = transformer.transform(train_df).astype(np.float32)

del train_df

sample_weights = compute_sample_weight(class_weight='balanced', y=y)
model.fit(X_transformed, y, sample_weight=sample_weights)

test_df = pd.read_csv("data/split_data_test.csv")
y_test = test_df['TARGET'].astype(np.float32)
X_test = test_df.drop(columns=['TARGET'])
transformed_test_df = transformer.transform(X_test).astype(np.float32)

del X_test

y_probs = model.predict_proba(X=transformed_test_df)[:, 1]
y_pred  = model.predict(X=transformed_test_df)

result = pd.DataFrame({
    'library': ["scikit-learn"],
    'algorithm': ['MLPClassifier'],
    'hyerparamters':[str(model.get_params())],
    'accuracy': [accuracy_score(y_test, y_pred)],
    'auc': [roc_auc_score(y_test, y_probs)]
}, index=None)

print(result.T)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    0
# library                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 scikit-learn
# algorithm                                                                                                                                                                                                                                                                                                                                                                                                                                                                               MLPClassifier + GridSearchCV
# hyerparamters  {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 32, 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 300, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': None, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# accuracy                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    0.754329
# auc                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         0.831157
