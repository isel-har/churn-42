# %%
import os

import pandas as pd
import numpy as np
import sklearn
import joblib
import tensorflow as tf

import keras_tuner as kt

from keras.losses import BinaryCrossentropy
from keras.layers import Dense, Dropout, Input
from keras.models import Sequential
from keras.optimizers import Adam
from keras.models import Sequential
from keras.metrics import AUC

from sklearn.metrics import roc_auc_score, accuracy_score
from sklearn.utils import class_weight

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
tf.get_logger().setLevel('ERROR')
# tf.config.optimizer.set_jit(True)
sklearn.set_config(transform_output="pandas")
pd.set_option('display.max_colwidth', None)



transformer   = joblib.load("transformer.pkl")
train_df      = pd.read_csv("data/balanced_train_data.csv")

y_train       = train_df['TARGET'].copy().astype(np.float32)
train_df      = train_df.drop(columns=['TARGET'])
X_transformed = transformer.transform(train_df).astype(np.float32)
del train_df



weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)
dict_weights = dict(enumerate(weights))


def build_model(hp):
    model = Sequential([
        Input(shape=(X_transformed.shape[1],)),
        Dense(
            units=hp.Int('units', min_value=32, max_value=128, step=32),
            activation=hp.Choice('activation', values=['relu']),
        ),
        Dense(1, activation='sigmoid')
    ])

    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='binary_crossentropy',
        # Added AUC to metrics so the tuner can track it
        metrics=[AUC(name='auc'), 'accuracy'] 
    )
    return model


tuner = kt.GridSearch(
    build_model,
    objective=kt.Objective("val_auc", direction="max"),
    directory="tuner_dir",
    project_name="auc_search"
)


tuner.search(
    X_transformed, 
    y_train, 
    batch_size=64, 
    epochs=200, 
    validation_split=0.2,
    class_weight=dict_weights 
)

best_hps = tuner.get_best_hyperparameters()[0]



del X_transformed, y_train

test_df = pd.read_csv("data/split_data_test.csv")
y_test = test_df['TARGET'].astype(np.float32)
X_test = test_df.drop(columns=['TARGET'])
X_transformed_test = transformer.transform(X_test).astype(np.float32)

del X_test

y_prob = tuner.predict(X_transformed_test).ravel()
auc    = roc_auc_score(y_test, y_prob)
y_pred = (y_prob > 0.5).astype(int)

result = pd.DataFrame({
    'library': ["scikit-learn, keras"],
    'algorithm': ['Multilayer-perceptron'],
    'Accuracy': [accuracy_score(y_test, y_pred)],
    'AUC': [roc_auc_score(y_test, y_prob)]
}, index=None)

model.summary()
print(result.T)
# Out:
# Search: Running Trial #1
#
# Value             |Best Value So Far |Hyperparameter
# 32                |32                |units
# relu              |relu              |activation
#
# Epoch 1/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6682 - auc: 0.7605 - loss: 0.5804 - val_accuracy: 0.6838 - val_auc: 0.8022 - val_loss: 0.5654
# Epoch 2/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6981 - auc: 0.8066 - loss: 0.5318 - val_accuracy: 0.7048 - val_auc: 0.8099 - val_loss: 0.5421
# Epoch 3/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7053 - auc: 0.8156 - loss: 0.5210 - val_accuracy: 0.7050 - val_auc: 0.8158 - val_loss: 0.5387
# Epoch 4/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7115 - auc: 0.8209 - loss: 0.5142 - val_accuracy: 0.7219 - val_auc: 0.8212 - val_loss: 0.5179
# Epoch 5/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7147 - auc: 0.8248 - loss: 0.5095 - val_accuracy: 0.7039 - val_auc: 0.8228 - val_loss: 0.5426
# Epoch 6/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7158 - auc: 0.8280 - loss: 0.5049 - val_accuracy: 0.7334 - val_auc: 0.8240 - val_loss: 0.5067
# Epoch 7/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7190 - auc: 0.8304 - loss: 0.5018 - val_accuracy: 0.7077 - val_auc: 0.8242 - val_loss: 0.5466
# Epoch 8/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7201 - auc: 0.8318 - loss: 0.4998 - val_accuracy: 0.6983 - val_auc: 0.8268 - val_loss: 0.5479
# Epoch 9/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7190 - auc: 0.8334 - loss: 0.4976 - val_accuracy: 0.7131 - val_auc: 0.8243 - val_loss: 0.5288
# Epoch 10/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.7208 - auc: 0.8344 - loss: 0.4961 - val_accuracy: 0.7086 - val_auc: 0.8271 - val_loss: 0.5375
# Epoch 11/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7230 - auc: 0.8362 - loss: 0.4939 - val_accuracy: 0.7001 - val_auc: 0.8264 - val_loss: 0.5557
# Epoch 12/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7232 - auc: 0.8371 - loss: 0.4928 - val_accuracy: 0.7255 - val_auc: 0.8269 - val_loss: 0.5077
# Epoch 13/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7237 - auc: 0.8374 - loss: 0.4922 - val_accuracy: 0.7339 - val_auc: 0.8293 - val_loss: 0.4948
# Epoch 14/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7241 - auc: 0.8386 - loss: 0.4902 - val_accuracy: 0.7129 - val_auc: 0.8308 - val_loss: 0.5271
# Epoch 15/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7257 - auc: 0.8397 - loss: 0.4887 - val_accuracy: 0.7178 - val_auc: 0.8289 - val_loss: 0.5197
# Epoch 16/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7247 - auc: 0.8401 - loss: 0.4882 - val_accuracy: 0.7155 - val_auc: 0.8306 - val_loss: 0.5257
# Epoch 17/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7258 - auc: 0.8408 - loss: 0.4873 - val_accuracy: 0.7184 - val_auc: 0.8314 - val_loss: 0.5180
# Epoch 18/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7268 - auc: 0.8416 - loss: 0.4865 - val_accuracy: 0.7031 - val_auc: 0.8304 - val_loss: 0.5437
# Epoch 19/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7271 - auc: 0.8422 - loss: 0.4856 - val_accuracy: 0.7344 - val_auc: 0.8307 - val_loss: 0.4936
# Epoch 20/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7284 - auc: 0.8427 - loss: 0.4849 - val_accuracy: 0.7417 - val_auc: 0.8283 - val_loss: 0.4819
# Epoch 21/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7284 - auc: 0.8433 - loss: 0.4839 - val_accuracy: 0.7091 - val_auc: 0.8292 - val_loss: 0.5268
# Epoch 22/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7293 - auc: 0.8434 - loss: 0.4837 - val_accuracy: 0.7253 - val_auc: 0.8315 - val_loss: 0.5155
# Epoch 23/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7282 - auc: 0.8440 - loss: 0.4828 - val_accuracy: 0.7399 - val_auc: 0.8328 - val_loss: 0.4864
# Epoch 24/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7287 - auc: 0.8444 - loss: 0.4822 - val_accuracy: 0.7538 - val_auc: 0.8328 - val_loss: 0.4706
# Epoch 25/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7297 - auc: 0.8445 - loss: 0.4820 - val_accuracy: 0.7077 - val_auc: 0.8340 - val_loss: 0.5361
# Epoch 26/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7298 - auc: 0.8452 - loss: 0.4810 - val_accuracy: 0.7191 - val_auc: 0.8327 - val_loss: 0.5198
# Epoch 27/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7305 - auc: 0.8455 - loss: 0.4807 - val_accuracy: 0.7223 - val_auc: 0.8335 - val_loss: 0.5143
# Epoch 28/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7300 - auc: 0.8457 - loss: 0.4805 - val_accuracy: 0.7089 - val_auc: 0.8301 - val_loss: 0.5444
# Epoch 29/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7316 - auc: 0.8463 - loss: 0.4796 - val_accuracy: 0.7238 - val_auc: 0.8343 - val_loss: 0.5133
# Epoch 30/200
# 2842/2842 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7314 - auc: 0.8467 - loss: 0.4794 - val_accuracy: 0.7294 - val_auc: 0.8337 - val_loss: 0.5070
# Epoch 31/200
# 2693/2842 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7289 - auc: 0.8455 - loss: 0.4815
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_491479/4099000515.py in <module>
#      72
#      73
# ---> 74 tuner.search(
#      75     X_transformed,
#      76     y_train,
#
# ~/.local/lib/python3.10/site-packages/keras_tuner/src/engine/base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     232
#     233             self.on_trial_begin(trial)
# --> 234             self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     235             self.on_trial_end(trial)
#     236         self.on_search_end()
#
# ~/.local/lib/python3.10/site-packages/keras_tuner/src/engine/base_tuner.py in _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     272     def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     273         try:
# --> 274             self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     275             trial.status = trial_module.TrialStatus.COMPLETED
#     276             return
#
# ~/.local/lib/python3.10/site-packages/keras_tuner/src/engine/base_tuner.py in _run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     237
#     238     def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 239         results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     240         if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     241             self.oracle.objective.name
#
# ~/.local/lib/python3.10/site-packages/keras_tuner/src/engine/tuner.py in run_trial(self, trial, *args, **kwargs)
#     312             callbacks.append(model_checkpoint)
#     313             copied_kwargs["callbacks"] = callbacks
# --> 314             obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     315
#     316             histories.append(obj_value)
#
# ~/.local/lib/python3.10/site-packages/keras_tuner/src/engine/tuner.py in _build_and_fit_model(self, trial, *args, **kwargs)
#     231         hp = trial.hyperparameters
#     232         model = self._try_build(hp)
# --> 233         results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     234
#     235         # Save the build config for model loading later.
#
# ~/.local/lib/python3.10/site-packages/keras_tuner/src/engine/hypermodel.py in fit(self, hp, model, *args, **kwargs)
#     147             If return a float, it should be the `objective` value.
#     148         """
# --> 149         return model.fit(*args, **kwargs)
#     150
#     151
#
# ~/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/.local/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397                 for begin_step, end_step, iterator in epoch_iterator:
#     398                     callbacks.on_train_batch_begin(begin_step)
# --> 399                     logs = self.train_function(iterator)
#     400                     callbacks.on_train_batch_end(end_step, logs)
#     401                     if self.stop_training:
#
# ~/.local/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     239                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240             ):
# --> 241                 opt_outputs = multi_step_on_iterator(iterator)
#     242                 if not opt_outputs.has_value():
#     243                     raise StopIteration
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     162     filtered_tb = None
#     163     try:
# --> 164       return fn(*args, **kwargs)
#     165     except Exception as e:
#     166       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1686     cancellation_context = cancellation.context()
#    1687     if cancellation_context is None:
# -> 1688       outputs = execute.execute(
#    1689           name.decode("utf-8"),
#    1690           num_outputs=num_outputs,
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
