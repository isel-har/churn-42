# %%
import pandas as pd
import joblib
import sklearn


from sklearn.metrics import  roc_auc_score, accuracy_score
from sklearn.model_selection import GridSearchCV
from lib.nn_wrapper import NNetWrapper
import numpy as np


sklearn.set_config(transform_output="pandas")
pd.set_option('display.max_colwidth', None)

preprocessor = joblib.load("transformer.pkl")

df = pd.read_csv("data/balanced_train_data.csv")
val_df = pd.read_csv("data/split_data_val.csv")

y  = df['TARGET'].copy().astype(np.float32)
df = df.drop(columns=['TARGET'])
X_transformed = preprocessor.transform(df).astype(np.float32)

y_val = val_df['TARGET'].copy().astype(np.float32)
val_df = val_df.drop(columns=['TARGET'])
X_val_transformed = preprocessor.transform(val_df).astype(np.float32)

del df, val_df

best_model = NNetWrapper(drop_rate=0.2, early_stopping_patience=40)
best_model.fit(X_transformed, y, validation_data=(X_val_transformed, y_val))

del X_transformed, y

test_split_df = pd.read_csv('data/split_data_test.csv')

y_test        = test_split_df['TARGET'].astype(np.float32)
test_split_df = test_split_df.drop(columns=['TARGET'])
X_test_split  = preprocessor.transform(test_split_df).astype(np.float32)


y_prob    = best_model.predict_proba(X_test_split)
y_pred    = (y_prob > 0.5).astype(int)

print("AUC :", roc_auc_score(y_test, y_prob))
# best_params  = {
#         'learning_rate':best_model.learning_rate,
#         'epochs':best_model.epochs,
#         'batch_size':best_model.batch_size,
#         'hidden_layers':'(64, 32, 16)',
#         'early_stopping': best_model.early_stopping_patience,
#         'drop_rate' : best_model.drop_rate,
#         'restore_best_weights': best_model.restore_best_weights
#     }
    
# result = pd.DataFrame({
#         'library': ["scikit-learn, tensorflow"],
#         'algorithm': ['Multilayer-perceptron'],
#         'hyerparamters': [str(best_params)],
#         'accuracy': [accuracy_score(y_test, y_pred)],
#         'auc': [roc_auc_score(y_test, y_prob)]
#     }, index=None)
    
# print(result.T)


# del test_split_df, X_test_split, y_test, y_pred
df = pd.read_csv("data/bank_data_test.csv")
ids = df['ID'].values.tolist()
X_test = preprocessor.transform(df).astype(np.float32)
y_pred = best_model.predict_proba(X_test)
preds_df = pd.DataFrame(data={'ID':ids, 'TARGET':y_pred.ravel().tolist()}, columns=['ID', 'TARGET'])
preds_df.to_csv("prediction_file.csv", index=False)
print("prediction_file.csv saved")
# Out:
# Epoch 1/300
# val loss : 11.39684854809979 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 2/300
# val loss : 0.2694937561872588 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 3/300
# val loss : 0.24809333473647205 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 4/300
# val loss : 0.24205610368675032 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 5/300
# val loss : 0.23776264367965172 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 6/300
# val loss : 0.23519533286302272 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 7/300
# val loss : 0.23312850718603478 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 8/300
# val loss : 0.23171518483312717 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 9/300
# val loss : 0.2301801241200203 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 10/300
# val loss : 0.229457116457893 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 11/300
# val loss : 0.22783183645521773 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 12/300
# val loss : 0.22704521060782268 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 13/300
# val loss : 0.2274326225598532 EarlyStopping counter: 1 out of 40
# 100%|===============================================================================================
# Epoch 14/300
# val loss : 0.22613963736956683 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 15/300
# val loss : 0.2264805207433341 EarlyStopping counter: 1 out of 40
# 100%|===============================================================================================
# Epoch 16/300
# val loss : 0.22611565369193276 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 17/300
# val loss : 0.22562902786863448 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 18/300
# val loss : 0.22503118645779552 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 19/300
# val loss : 0.22567364020847974 EarlyStopping counter: 1 out of 40
# 100%|===============================================================================================
# Epoch 20/300
# val loss : 0.2256842119369874 EarlyStopping counter: 2 out of 40
# 100%|===============================================================================================
# Epoch 21/300
# val loss : 0.22497185984119786 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 22/300
# val loss : 0.2245718982194133 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 23/300
# val loss : 0.22419586043346942 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 24/300
# val loss : 0.22455798738897612 EarlyStopping counter: 1 out of 40
# 100%|===============================================================================================
# Epoch 25/300
# val loss : 0.22406252040353913 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 26/300
# val loss : 0.22414794244997602 EarlyStopping counter: 1 out of 40
# 100%|===============================================================================================
# Epoch 27/300
# val loss : 0.22352992315221176 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 28/300
# val loss : 0.22491835650179928 EarlyStopping counter: 1 out of 40
# 100%|===============================================================================================
# Epoch 29/300
# val loss : 0.22282490296151786 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 30/300
# val loss : 0.22411649505521564 EarlyStopping counter: 1 out of 40
# 100%|===============================================================================================
# Epoch 31/300
# val loss : 0.22350663027780932 EarlyStopping counter: 2 out of 40
# 100%|===============================================================================================
# Epoch 32/300
# val loss : 0.22443546407114492 EarlyStopping counter: 3 out of 40
# 100%|===============================================================================================
# Epoch 33/300
# val loss : 0.22479617090683796 EarlyStopping counter: 4 out of 40
# 100%|===============================================================================================
# Epoch 34/300
# val loss : 0.22411386594831262 EarlyStopping counter: 5 out of 40
# 100%|===============================================================================================
# Epoch 35/300
# val loss : 0.22411013055102277 EarlyStopping counter: 6 out of 40
# 100%|===============================================================================================
# Epoch 36/300
# val loss : 0.2233102268637513 EarlyStopping counter: 7 out of 40
# 100%|===============================================================================================
# Epoch 37/300
# val loss : 0.22320018379837653 EarlyStopping counter: 8 out of 40
# 100%|===============================================================================================
# Epoch 38/300
# val loss : 0.2242450102420907 EarlyStopping counter: 9 out of 40
# 100%|===============================================================================================
# Epoch 39/300
# val loss : 0.2235770624492449 EarlyStopping counter: 10 out of 40
# 100%|===============================================================================================
# Epoch 40/300
# val loss : 0.22335202141739643 EarlyStopping counter: 11 out of 40
# 100%|===============================================================================================
# Epoch 41/300
# val loss : 0.2232326715383597 EarlyStopping counter: 12 out of 40
# 100%|===============================================================================================
# Epoch 42/300
# val loss : 0.2227418569032056 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 43/300
# val loss : 0.22408595962248476 EarlyStopping counter: 1 out of 40
# 100%|===============================================================================================
# Epoch 44/300
# val loss : 0.2241760830014297 EarlyStopping counter: 2 out of 40
# 100%|===============================================================================================
# Epoch 45/300
# val loss : 0.22394769101221193 EarlyStopping counter: 3 out of 40
# 100%|===============================================================================================
# Epoch 46/300
# val loss : 0.22321942692806404 EarlyStopping counter: 4 out of 40
# 100%|===============================================================================================
# Epoch 47/300
# val loss : 0.22358225072717614 EarlyStopping counter: 5 out of 40
# 100%|===============================================================================================
# Epoch 48/300
# val loss : 0.22212454073930174 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 49/300
# val loss : 0.22384462607254238 EarlyStopping counter: 1 out of 40
# 100%|===============================================================================================
# Epoch 50/300
# val loss : 0.22408657695654616 EarlyStopping counter: 2 out of 40
# 100%|===============================================================================================
# Epoch 51/300
# val loss : 0.2241245079283774 EarlyStopping counter: 3 out of 40
# 100%|===============================================================================================
# Epoch 52/300
# val loss : 0.22402002943145655 EarlyStopping counter: 4 out of 40
# 100%|===============================================================================================
# Epoch 53/300
# val loss : 0.2238326154212391 EarlyStopping counter: 5 out of 40
# 100%|===============================================================================================
# Epoch 54/300
# val loss : 0.2237745042010135 EarlyStopping counter: 6 out of 40
# 100%|===============================================================================================
# Epoch 55/300
# val loss : 0.2234591245178703 EarlyStopping counter: 7 out of 40
# 100%|===============================================================================================
# Epoch 56/300
# val loss : 0.2235918568987078 EarlyStopping counter: 8 out of 40
# 100%|===============================================================================================
# Epoch 57/300
# val loss : 0.2237489897043008 EarlyStopping counter: 9 out of 40
# 100%|===============================================================================================
# Epoch 58/300
# val loss : 0.22293949426505158 EarlyStopping counter: 10 out of 40
# 100%|===============================================================================================
# Epoch 59/300
# val loss : 0.22385159968046767 EarlyStopping counter: 11 out of 40
# 100%|===============================================================================================
# Epoch 60/300
# val loss : 0.22361785297205344 EarlyStopping counter: 12 out of 40
# 100%|===============================================================================================
# Epoch 61/300
# val loss : 0.22353623834633632 EarlyStopping counter: 13 out of 40
# 100%|===============================================================================================
# Epoch 62/300
# val loss : 0.22354818857348246 EarlyStopping counter: 14 out of 40
# 100%|===============================================================================================
# Epoch 63/300
# val loss : 0.2223256500777222 EarlyStopping counter: 15 out of 40
# 100%|===============================================================================================
# Epoch 64/300
# val loss : 0.22362714789287416 EarlyStopping counter: 16 out of 40
# 100%|===============================================================================================
# Epoch 65/300
# val loss : 0.22420077972363925 EarlyStopping counter: 17 out of 40
# 100%|===============================================================================================
# Epoch 66/300
# val loss : 0.22183782847586464 Validation loss decreased. Resetting counter.
# 100%|===============================================================================================
# Epoch 67/300
# val loss : 0.2229008388130849 EarlyStopping counter: 1 out of 40
# 100%|===============================================================================================
# Epoch 68/300
# val loss : 0.22416300164795958 EarlyStopping counter: 2 out of 40
# 100%|===============================================================================================
# Epoch 69/300
# val loss : 0.2237226165286134 EarlyStopping counter: 3 out of 40
# 100%|===============================================================================================
# Epoch 70/300
# val loss : 0.22330972335726545 EarlyStopping counter: 4 out of 40
# 100%|===============================================================================================
# Epoch 71/300
# val loss : 0.22296207873709384 EarlyStopping counter: 5 out of 40
# 100%|===============================================================================================
# Epoch 72/300
# val loss : 0.22349087839053972 EarlyStopping counter: 6 out of 40
# 100%|===============================================================================================
# Epoch 73/300
# val loss : 0.22300464763046401 EarlyStopping counter: 7 out of 40
# 100%|===============================================================================================
# Epoch 74/300
# val loss : 0.2238922124203471 EarlyStopping counter: 8 out of 40
# 100%|===============================================================================================
# Epoch 75/300
# val loss : 0.22369448517923318 EarlyStopping counter: 9 out of 40
# 100%|===============================================================================================
# Epoch 76/300
# val loss : 0.22264437150673516 EarlyStopping counter: 10 out of 40
# 100%|===============================================================================================
# Epoch 77/300
# val loss : 0.2231260964884392 EarlyStopping counter: 11 out of 40
# 100%|===============================================================================================
# Epoch 78/300
# val loss : 0.22360134861196626 EarlyStopping counter: 12 out of 40
# 100%|===============================================================================================
# Epoch 79/300
# val loss : 0.22392483051648862 EarlyStopping counter: 13 out of 40
# 100%|===============================================================================================
# Epoch 80/300
# val loss : 0.22338936836554607 EarlyStopping counter: 14 out of 40
# 100%|===============================================================================================
# Epoch 81/300
# val loss : 0.2237376123944779 EarlyStopping counter: 15 out of 40
# 100%|===============================================================================================
# Epoch 82/300
# val loss : 0.22281789210243513 EarlyStopping counter: 16 out of 40
# 100%|===============================================================================================
# Epoch 83/300
# val loss : 0.22303961586748028 EarlyStopping counter: 17 out of 40
# 100%|===============================================================================================
# Epoch 84/300
# val loss : 0.2243928996463455 EarlyStopping counter: 18 out of 40
# 100%|===============================================================================================
# Epoch 85/300
# val loss : 0.22282152345930348 EarlyStopping counter: 19 out of 40
# 100%|===============================================================================================
# Epoch 86/300
# val loss : 0.22351246476161235 EarlyStopping counter: 20 out of 40
# 100%|===============================================================================================
# Epoch 87/300
# val loss : 0.2233611978327043 EarlyStopping counter: 21 out of 40
# 100%|===============================================================================================
# Epoch 88/300
# val loss : 0.22436463317693567 EarlyStopping counter: 22 out of 40
# 100%|===============================================================================================
# Epoch 89/300
# val loss : 0.22335150743574514 EarlyStopping counter: 23 out of 40
# 100%|===============================================================================================
# Epoch 90/300
# val loss : 0.22318709485484292 EarlyStopping counter: 24 out of 40
# 100%|===============================================================================================
# Epoch 91/300
# val loss : 0.22353582361650015 EarlyStopping counter: 25 out of 40
# 100%|===============================================================================================
# Epoch 92/300
# val loss : 0.22409989108287906 EarlyStopping counter: 26 out of 40
# 100%|===============================================================================================
# Epoch 93/300
# val loss : 0.22445744864321165 EarlyStopping counter: 27 out of 40
# 100%|===============================================================================================
# Epoch 94/300
# val loss : 0.22357243395992335 EarlyStopping counter: 28 out of 40
# 100%|===============================================================================================
# Epoch 95/300
# val loss : 0.22430677661489276 EarlyStopping counter: 29 out of 40
# 100%|===============================================================================================
# Epoch 96/300
# val loss : 0.223773805457403 EarlyStopping counter: 30 out of 40
# 100%|===============================================================================================
# Epoch 97/300
# val loss : 0.22416013487416991 EarlyStopping counter: 31 out of 40
# 100%|===============================================================================================
# Epoch 98/300
# val loss : 0.2240058549666178 EarlyStopping counter: 32 out of 40
# 100%|===============================================================================================
# Epoch 99/300
# val loss : 0.223864345400391 EarlyStopping counter: 33 out of 40
# 100%|===============================================================================================
# Epoch 100/300
# val loss : 0.22323985530422727 EarlyStopping counter: 34 out of 40
# 100%|===============================================================================================
# Epoch 101/300
# val loss : 0.22362599175132142 EarlyStopping counter: 35 out of 40
# 100%|===============================================================================================
# Epoch 102/300
# val loss : 0.22410415361155933 EarlyStopping counter: 36 out of 40
# 100%|===============================================================================================
# Epoch 103/300
# val loss : 0.22351878873780615 EarlyStopping counter: 37 out of 40
# 100%|===============================================================================================
# Epoch 104/300
# val loss : 0.22287264702444876 EarlyStopping counter: 38 out of 40
# 100%|===============================================================================================
# Epoch 105/300
# val loss : 0.2245108166179094 EarlyStopping counter: 39 out of 40
# 100%|===============================================================================================
# Epoch 106/300
# val loss : 0.22357586729826356 EarlyStopping counter: 40 out of 40
# AUC : 0.8396637615061253
# prediction_file.csv saved

# %%
hyerparamters  {'learning_rate': 0.001, 'epochs': 300, 'batch_size': 256, 'hidden_layers': '(64, 32, 16)', 'early_stopping': 30, 'drop_rate': 0.2, 'restore_best_weights': True}
